# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadQuthbulAlam/Aplikasi-Login/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## IMPORT DATA

# %%
df = pd.read_csv('/content/drive/MyDrive/datasheet diabetes/diabetes_prediction_dataset.csv', index_col=0)
df
# Out:
#          age  hypertension  heart_disease smoking_history    bmi  HbA1c_level  \
# gender
# Female  80.0             0              1           never  25.19          6.6
# Female  54.0             0              0         No Info  27.32          6.6
# Male    28.0             0              0           never  27.32          5.7
# Female  36.0             0              0         current  23.45          5.0
# Male    76.0             1              1         current  20.14          4.8
# ...      ...           ...            ...             ...    ...          ...
# Female  80.0             0              0         No Info  27.32          6.2
# Female   2.0             0              0         No Info  17.37          6.5
# Male    66.0             0              0          former  27.83          5.7
# Female  24.0             0              0           never  35.42          4.0
# Female  57.0             0              0         current  22.43          6.6
#
# ...

# %% [markdown]
# ## DATA UNDERSTANDING

# %%
print('data shape: ', df.shape)
# Out:
# data shape:  (100000, 8)

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, Female to Female
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   age                  100000 non-null  float64
#  1   hypertension         100000 non-null  int64
#  2   heart_disease        100000 non-null  int64
#  3   smoking_history      100000 non-null  object
#  4   bmi                  100000 non-null  float64
#  5   HbA1c_level          100000 non-null  float64
#  6   blood_glucose_level  100000 non-null  int64
#  7   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 8.9+ MB

# %%
df[['age','hypertension','heart_disease','smoking_history','bmi','blood_glucose_level',]].describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#        blood_glucose_level
# count        100000.000000
# mean            138.058060
# std              40.708136
# min              80.000000
# 25%             100.000000
# 50%             140.000000
# 75%             159.000000
# max             300.000000

# %%
df.diabetes.value_counts()
# Out:
# 0    91500
# 1     8500
# Name: diabetes, dtype: int64

# %% [markdown]
# ## CLEANING DATA

# %%
df.isnull().sum()
# Out:
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6389

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=df, x='age', bins=10, kde=True, color='#91008a')

plt.title('distibusi umur')
plt.xlabel('umur')
plt.ylabel('frekuensi')
plt.show()

# %%
sns.set_palette('pastel')
df['diabetes'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('presentase diabetes vs non diabetes')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x='diabetes',palette='rocket')

plt.title('distribusi hasil diagnosis')
plt.xlabel('hasil / label')
plt.ylabel('frekuensi')
plt.show()

# %%
df.corr()
# Out:
# <ipython-input-35-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           age  hypertension  heart_disease       bmi  \
# age                  1.000000      0.251171       0.233354  0.337396
# hypertension         0.251171      1.000000       0.121262  0.147666
# heart_disease        0.233354      0.121262       1.000000  0.061198
# bmi                  0.337396      0.147666       0.061198  1.000000
# HbA1c_level          0.101354      0.080939       0.067589  0.082997
# blood_glucose_level  0.110672      0.084429       0.070066  0.091261
# diabetes             0.258008      0.197823       0.171727  0.214357
#
#                      HbA1c_level  blood_glucose_level  diabetes
# age                     0.101354             0.110672  0.258008
# ...

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df.corr(),cmap='BuPu')
# Out:
# <ipython-input-41-92c2d0d57910>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='BuPu')
# <Axes: >

# %% [markdown]
# ## PREPERATION DATA

# %%
X= df.drop(columns=['diabetes'])
Y= df['diabetes']

print("X : ", X.shape)
print("Y : ", Y.shape)
# Out:
# X :  (100000, 7)
# Y :  (100000,)

# %%
X =df.drop(columns=['smoking_history','diabetes'])
print(X.shape)
# Out:
# (100000, 6)

# %%
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## MODELING AND EVALUATION

# %%
clf = SVC(kernel='linear')
clf.fit(X_train, Y_train)

Y_pred = clf.predict(X_test)
CLF_acc = accuracy_score(Y_pred, Y_test)

print(classification_report(Y_test, Y_pred))
print("akurasi SVM : {:.2f}%".format(CLF_acc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     18292
#            1       0.92      0.56      0.70      1708
#
#     accuracy                           0.96     20000
#    macro avg       0.94      0.78      0.84     20000
# weighted avg       0.96      0.96      0.95     20000
#
# akurasi SVM : 95.86%

# %% [markdown]
# ## TESTING

# %%
new_data = {'age': [80],
            'hypertension': [1],
            'heart_disease': [1],
            'bmi' : [30],
            'HbA1c_level' : [4],
            'blood_glucose_level': [140]	}
new_data = pd.DataFrame(new_data)
new_data
# Out:
#    age  hypertension  heart_disease  bmi  HbA1c_level  blood_glucose_level
# 0   80             1              1   30            4                  140

# %%
scaled_new_data = scaler.transform(new_data)
Y_pred_new = clf.predict(scaled_new_data)

print("Diagnosis Data Baru :", Y_pred_new)
# Out:
# Diagnosis Data Baru : [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
